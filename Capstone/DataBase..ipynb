# %% [markdown]
# This Database contains most of the data that I need in order to complete my desired outcomes for my project. There is still a bit of additional data that I am looking for/cleaning that will be completed over the Christmas period.

# %% [markdown]
# The idea of my Project is to predict crop output via a variety of different factors that can include country of origin and tyope of crop. Global Weather statistics is still in the works as of now.

# %% [markdown]
# The data that has been obtained allows me to focus on a particular region of the UK in great detail, every region of Argentina, every country in Europe and every single country in the world. All regions of the UK is still in the works however there is very little data to use (i.e. only about 10 bits of data).

# %% [markdown]
# Below are labelled dictionaries describing the column inputs of each data set.

# %%
import pandas as pd
import numpy as np

# %%
Argentina = pd.read_csv('../../../DSI7-project-submissions/Capstone/Argentina.csv')

# %%
Argentina.columns = [['Title','Description']]

# %%
Argentina
# Out:
#        Title                                        Description
# 0       Year  This states the year of which the samples were...
# 1  Treatment  The treatment states the level of Organic trea...
# 2  FieldName      The name of the field in the region of the UK
# 3  FieldArea                  The area in Hectares of the Field
# 4       Crop  The type of crop harvested from the field whic...
# 5      Yield          The amount of crop per hectare harvested.
# 6     tonnes  The number of tonnes of crop per hectare harve...
# 7      Ratio  The ratio of crop harvested to tonne harvested...

# %%
Argentina.to_dict()
# Out:
# {('Title',): {0: 'Year',
#   1: 'Treatment',
#   2: 'FieldName',
#   3: 'FieldArea',
#   4: 'Crop',
#   5: 'Yield',
#   6: 'tonnes',
#   7: 'Ratio'},
#  ('Description',): {0: 'This states the year of which the samples were taken. This ranges from 2006-2011',
#   1: 'The treatment states the level of Organic treatment that the field has been subject to. This is a range of 1 (Cross-Compliance) to 3 (Extra ELS)',
#   2: 'The name of the field in the region of the UK',
#   3: 'The area in Hectares of the Field',
#   4: 'The type of crop harvested from the field which is a variety of grains and cereals.',
#   5: 'The amount of crop per hectare harvested.',
#   6: 'The number of tonnes of crop per hectare harvested.',
#   7: 'The ratio of crop harvested to tonne harvested per hectare.'}}

# %% [markdown]
# This Data is taken from the Argentina crop dataset that was translated from their native Spanish tongue. If there are translation errors I apologise.

# %%
Hillstone = pd.read_csv('../../../DSI7-project-submissions/Capstone/Hillstone.csv')

# %%
Hillstone.columns = [['Title','Description']]

# %%
Hillstone
# Out:
#        Title                                        Description
# 0       Year  This states the year of which the samples were...
# 1  Treatment  The treatment states the level of Organic trea...
# 2  FieldName      The name of the field in the region of the UK
# 3  FieldArea                  The area in Hectares of the Field
# 4       Crop  The type of crop harvested from the field whic...
# 5      Yield          The amount of crop per hectare harvested.
# 6     tonnes  The number of tonnes of crop per hectare harve...
# 7      Ratio  The ratio of crop harvested to tonne harvested...

# %%
Hillstone.to_dict()
# Out:
# {('Title',): {0: 'Year',
#   1: 'Treatment',
#   2: 'FieldName',
#   3: 'FieldArea',
#   4: 'Crop',
#   5: 'Yield',
#   6: 'tonnes',
#   7: 'Ratio'},
#  ('Description',): {0: 'This states the year of which the samples were taken. This ranges from 2006-2011',
#   1: 'The treatment states the level of Organic treatment that the field has been subject to. This is a range of 1 (Cross-Compliance) to 3 (Extra ELS)',
#   2: 'The name of the field in the region of the UK',
#   3: 'The area in Hectares of the Field',
#   4: 'The type of crop harvested from the field which is a variety of grains and cereals.',
#   5: 'The amount of crop per hectare harvested.',
#   6: 'The number of tonnes of crop per hectare harvested.',
#   7: 'The ratio of crop harvested to tonne harvested per hectare.'}}

# %% [markdown]
# This data is from the Hillstone region of the UK. It provides very insightful levels of data including organinc practises.

# %%
Euro = pd.read_csv('../../../DSI7-project-submissions/Capstone/euro.csv')

# %%
Euro.columns = [['Title','Description']]

# %%
Euro
# Out:
#    Title                                        Description
# 0    Geo  The country of which the crop was harvested fr...
# 1   Time  The year of which the crop was harvested to se...
# 2  Crops  This is one of three different ‘crops’; Grassl...
# 3  Value      The amount of the crop harvested in the type.
# 4   Type  The type in which the value was harvested. Thi...

# %%
Euro.to_dict()
# Out:
# {('Title',): {0: 'Geo', 1: 'Time', 2: 'Crops', 3: 'Value', 4: 'Type'},
#  ('Description',): {0: 'The country of which the crop was harvested from. This includes every country from Europe including some regions from each country.',
#   1: 'The year of which the crop was harvested to see the change in crop harvest. Ranges from 2009 - 2018.',
#   2: 'This is one of three different ‘crops’; Grassland, Cereals and Dry pulses.',
#   3: 'The amount of the crop harvested in the type.',
#   4: 'The type in which the value was harvested. This is done in Hectares.'}}

# %% [markdown]
# This data was collected from Eurostat and after some general cleaning provides insight into types and amounts of crops that are obtained from each individual country as well.

# %%
World = pd.read_csv('../../../DSI7-project-submissions/Capstone/world_crops.csv')

# %%
World.columns = [['Title','Description']]

# %%
World
# Out:
#              Title                                        Description
# 0  Country_or_area  Contains the names of each country that is inc...
# 1             Year  This states the year that the data was collect...
# 2             Unit  This states the unit of measurement that the c...
# 3            Value  This states the quantity of the crop harvested...
# 4         Category  This states the type of crop harvested. This r...

# %%
World.to_dict()
# Out:
# {('Title',): {0: 'Country_or_area',
#   1: 'Year',
#   2: 'Unit',
#   3: 'Value',
#   4: 'Category'},
#  ('Description',): {0: 'Contains the names of each country that is included in the Dataset. This Includes Continents as a whole which will be moved to a new Dataset. Included are all the countries found on earth.',
#   1: 'This states the year that the data was collected. This ranges from 1961 to 2007. This data will be dummified to be able to show the change in crop production across the different years.',
#   2: 'This states the unit of measurement that the crop was collected in. The measurements are in Hectares, Tonnes, Hectograms per Hectares.',
#   3: 'This states the quantity of the crop harvested in the various states of Unit.',
#   4: 'This states the type of crop harvested. This ranges from Agave fibres to Buckwheat and tubers.'}}

# %% [markdown]
# This data shows every country in the world and their crop statistics. It even provides continental data which will be placed into a separate dataset to privide continent statistics too.

# %%
global_crops = pd.read_csv('../../../DSI7-project-submissions/Capstone/global_crops_.csv')

# %%
global_crops
# Out:
#       country_or_area    year    unit     value          category
# 0          Americas +  2007.0      Ha   49404.0  agave_fibres_nes
# 1          Americas +  2006.0      Ha   49404.0  agave_fibres_nes
# 2          Americas +  2005.0      Ha   49404.0  agave_fibres_nes
# 3          Americas +  2004.0      Ha   49113.0  agave_fibres_nes
# 4          Americas +  2003.0      Ha   48559.0  agave_fibres_nes
# 5          Americas +  2002.0      Ha   48506.0  agave_fibres_nes
# 6          Americas +  2001.0      Ha   47767.0  agave_fibres_nes
# 7          Americas +  2000.0      Ha   48747.0  agave_fibres_nes
# 8          Americas +  1999.0      Ha   46978.0  agave_fibres_nes
# 9          Americas +  1998.0      Ha   48571.0  agave_fibres_nes
# 10         Americas +  1997.0      Ha   50904.0  agave_fibres_nes
# 11         Americas +  1996.0      Ha   52755.0  agave_fibres_nes
# 12         Americas +  1995.0      Ha   44042.0  agave_fibres_nes
# ...
