# %%
import pandas as pd
import numpy as np

from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn import cluster
from sklearn.cluster import DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from scipy.spatial.distance import pdist, squareform

import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm_notebook

# %%
argentina = pd.read_csv('../../resource-datasets/capstone/argentina.csv')

# %%
argentina
# Out:
#          Unnamed: 0    Unnamed: 1       Unnamed: 2              Unnamed: 3  \
# 0      ID Provincia     Provincia  ID Departamento            Departamento
# 1                 6  BUENOS AIRES              854              25 DE MAYO
# 2                 6  BUENOS AIRES              854              25 DE MAYO
# 3                 6  BUENOS AIRES               14  ADOLFO GONZALES CHAVES
# 4                 6  BUENOS AIRES               14  ADOLFO GONZALES CHAVES
# 5                 6  BUENOS AIRES               14  ADOLFO GONZALES CHAVES
# 6                 6  BUENOS AIRES               14  ADOLFO GONZALES CHAVES
# 7                 6  BUENOS AIRES               14  ADOLFO GONZALES CHAVES
# 8                 6  BUENOS AIRES               14  ADOLFO GONZALES CHAVES
# 9                 6  BUENOS AIRES               14  ADOLFO GONZALES CHAVES
# 10                6  BUENOS AIRES               14  ADOLFO GONZALES CHAVES
# ...

# %%
argentina['Unnamed: 7'].unique()
# Out:
# array(['Campana', '1969/70', '1970/71', '1971/72', '1972/73', '1973/74',
#        '1974/75', '1975/76', '1976/77', '1977/78', '1978/79', '1979/80',
#        '1980/81', '1983/84', '1984/85', '1985/86', '1986/87', '1987/88',
#        '1981/82', '1982/83', '1989/90', '1990/91', '1991/92', '1992/93',
#        '1993/94', '1994/95', '1995/96', '1996/97', '1997/98', '1988/89',
#        '1999/00', '1998/99', '2008/09', '2000/01', '2001/02', '2002/03',
#        '2003/04', '2004/05', '2009/10', '2010/11', '2011/12', '2005/06',
#        '2006/07', '2007/08', '2012/13', '2013/14', '2014/15', '2015/16',
#        '2016/17'], dtype=object)

# %%
farm = pd.read_csv('../../resource-datasets/capstone/data.csv')

# %%
farm = pd.DataFrame(farm)

# %%
farm.LOCATION.unique()
# Out:
# array(['AUS', 'CAN', 'JPN', 'KOR', 'MEX', 'NZL', 'TUR', 'USA', 'ARG',
#        'BRA', 'CHL', 'CHN', 'COL', 'EGY', 'ETH', 'IND', 'IDN', 'IRN',
#        'KAZ', 'MYS', 'NGA', 'PAK', 'PRY', 'PHL', 'RUS', 'SAU', 'ZAF',
#        'THA', 'UKR', 'VNM', 'WLD', 'OECD', 'BRICS', 'NOR', 'CHE', 'EU28',
#        'ISR'], dtype=object)

# %% [markdown]
# - COL =Columbia,
# - IDN = Indonesia,
# - IRN = Iran,
# - KAZ = Khazakstan,
# - MYS = Malaysia,
# - NGA = Nigeria,
# - PRY = Paraguay,
# - PHL = Philippines,
# - ZAF = South Africa,
# - WLD = World,
# - OCED = Organisation for Economic Co-operation and Development
# - NOR = Norway,
# - CHE = Switzerland,
# - ISR = Israel,
# - EU28 = European Union,
# - BRICS = Brazil, Russia, India, China and South Africa.

# %%
farm
# Out:
#       LOCATION  INDICATOR  SUBJECT   MEASURE FREQUENCY  TIME         Value  \
# 0          AUS  CROPYIELD     RICE  TONNE_HA         A  1990      5.374114
# 1          AUS  CROPYIELD     RICE  TONNE_HA         A  1991      5.374114
# 2          AUS  CROPYIELD     RICE  TONNE_HA         A  1992      5.897753
# 3          AUS  CROPYIELD     RICE  TONNE_HA         A  1993      5.903150
# 4          AUS  CROPYIELD     RICE  TONNE_HA         A  1994      5.221311
# 5          AUS  CROPYIELD     RICE  TONNE_HA         A  1995      5.457576
# 6          AUS  CROPYIELD     RICE  TONNE_HA         A  1996      5.925000
# 7          AUS  CROPYIELD     RICE  TONNE_HA         A  1997      4.257047
# 8          AUS  CROPYIELD     RICE  TONNE_HA         A  1998      5.545181
# 9          AUS  CROPYIELD     RICE  TONNE_HA         A  1999      6.270739
# 10         AUS  CROPYIELD     RICE  TONNE_HA         A  2000      5.924013
# ...

# %%
global_food = pd.read_csv('../../resource-datasets/capstone/global_crops.csv')

# %%
global_food.country_or_area.unique()
# Out:
# array(['Americas +', 'Asia +', 'Caribbean +', 'Central America +',
#        'Colombia', 'Cuba', 'Ecuador', 'El Salvador', 'Guatemala',
#        'Low Income Food Deficit Countries +', 'Mexico',
#        'Net Food Importing Developing Countries +', 'Nicaragua',
#        'Philippines', 'Small Island Developing States +',
#        'South America +', 'South-Eastern Asia +', 'World +', 'fnSeqID',
#        'Fc', 'A ', 'NR', 'F ', '* ', 'Afghanistan', 'Africa +', 'Algeria',
#        'Argentina', 'Armenia', 'Australia', 'Australia and New Zealand +',
#        'Azerbaijan', 'Bosnia and Herzegovina', 'Bulgaria', 'Burkina Faso',
#        'Central Asia +', 'Chile', 'China', 'China, mainland',
#        "Côte d'Ivoire", 'Croatia', 'Cyprus', 'Eastern Asia +',
#        'Eastern Europe +', 'Europe +', 'European Union +', 'France',
#        'Georgia', 'Greece', 'Hungary', 'Iran, Islamic Republic of',
#        'Iraq', 'Israel', 'Italy', 'Jordan', 'Kazakhstan', 'Kyrgyzstan',
# ...

# %%
crop.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0fded0ac49d2> in <module>()
# ----> 1 crop.info()
#
# NameError: name 'crop' is not defined

# %%
crop = crop.drop(['Notes'], axis =1)

# %%
crop = crop.drop(['Unnamed: 11'], axis = 1)

# %%
, ['Unnamed: 12'], ['Unnamed: 13'], ['Unnamed: 14']

# %%
crop = crop.drop(['Unnamed: 12'], axis = 1)

# %%
crop = crop.drop(['Unnamed: 13'], axis = 1)

# %%
crop = crop.drop(['Unnamed: 14'], axis = 1)

# %%
crop

# %%
crop.Crop.unique()

# %%
crop.Treatment.unique()

# %%
crop['Defra SE regional average yield t/ha'].unique()

# %%
farm.head()

# %%
farm = farm.drop(['Flag Codes'], axis=1)

# %%
farm.LOCATION.value_counts()

# %%
global_food

# %%
globe_year = pd.DataFrame(global_food['year'])

# %%
globe_value = pd.DataFrame(global_food['value'])

# %%
plt.scatter(globe_value, globe_year)

# %%
globe_area =(global_food['country_or_area'])

# %%
global_food.country_or_area.unique()

# %%
food = global_food.dropna()

# %%
food

# %%
country = food.groupby(['country_or_area'])

# %%
mean_country = country.mean()
mean_country

# %%
j = country.category.max()
j.value_counts()

# %%
crop_group = crop.groupby(['Crop'])

# %%
crop_group.max()
# Out:
#               Year  Block  Treatment     Field Name  Field Area  Quantity  \
# Crop
# Beans         2011      5  ELS extra     Top warren       28.43     83.61
# Oilseed Rape  2011      1  ELS extra  Rowley Meadow       11.47     56.25
# Oilseed rape  2011      5  ELS extra     Top warren       27.60    123.00
# Wheat         2011      5  ELS extra     Top warren       28.43    290.00
# Wheat_2nd     2009      3  ELS extra    Thieves Den       21.77    164.00
#
#               Yield/ha  Defra SE regional average yield t/ha  Ratio
# Crop
# Beans            5.200                                   4.5  1.348
# Oilseed Rape     5.208                                   4.0  1.302
# Oilseed rape     5.930                                   4.0  1.482
# Wheat           12.484                                   8.3  1.561
# Wheat_2nd       12.211                                   8.3  1.489

# %%
crop.isnull().sum()
# Out:
# Year                                    0
# Block                                   0
# Treatment                               0
# Field Name                              0
# Field Area                              0
# Crop                                    0
# Quantity                                0
# Yield/ha                                0
# Defra SE regional average yield t/ha    0
# Ratio                                   0
# dtype: int64

# %%
crop.Crop.value_counts()
# Out:
# Wheat           164
# Oilseed rape    124
# Beans            44
# Wheat_2nd         7
# Oilseed Rape      3
# Name: Crop, dtype: int64
